# %% [markdown]
# <a href="https://colab.research.google.com/github/milka513/Gepi_tanulas_beadando/blob/master/worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
listings_data2=pd.read_csv('./files/listings.csv')
listings_data2
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# 5          9991                Geourgeous flat - outstanding views      33852
# 6         14325                       Apartment in Prenzlauer Berg      55531
# 7         16401                                  APARTMENT TO RENT      59666
# 8         16644                 In the Heart of Berlin - Kreuzberg      64696
# 9         17409                 Downtown Above The Roofs In Berlin      67590
# 10        17904       Beautiful Kreuzberg studio/WiFi (reg. pend.)      68997
# ...

# %%
listings_data=pd.read_csv('summed_data2.csv')



temp=pd.read_csv('./files/listings_summary.csv')
temp[['accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
     'square_feet', 'amenities']]
#listings_data=pd.merge(listings_data, temp, how='inner', left_on=['id'], right_on=['id'])
#listings_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-1e81ef7e7bb5> in <module>()
#       5 temp=pd.read_csv('./files/listings_summary.csv')
#       6 temp[['accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
# ----> 7      'square_feet', 'amenities', 'sequrity_deposit']]
#       8 #listings_data=pd.merge(listings_data, temp, how='inner', left_on=['id'], right_on=['id'])
#       9 #listings_data
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ...
